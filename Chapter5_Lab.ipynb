# %% [markdown]
# ## 5.3 実習: 交差検証とブートストラップ

# %%
import time
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split, LeaveOneOut, KFold
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error as mse
from sklearn.preprocessing import PolynomialFeatures as PF

# %% [markdown]
# #### データの読み込み

# %%
dataset_path = "./datasets/Auto 2.csv"
df = pd.read_csv(dataset_path, index_col=0)
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 1    18.0          8         307.0         130    3504          12.0    70
# 2    15.0          8         350.0         165    3693          11.5    70
# 3    18.0          8         318.0         150    3436          11.0    70
# 4    16.0          8         304.0         150    3433          12.0    70
# 5    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 393  27.0          4         140.0          86    2790          15.6    82
# 394  44.0          4          97.0          52    2130          24.6    82
# 395  32.0          4         135.0          84    2295          11.6    82
# 396  28.0          4         120.0          79    2625          18.6    82
# 397  31.0          4         119.0          82    2720          19.4    82
#
#      origin                       name
# 1         1  chevrolet chevelle malibu
# 2         1          buick skylark 320
# 3         1         plymouth satellite
# 4         1              amc rebel sst
# 5         1                ford torino
# ..      ...                        ...
# 393       1            ford mustang gl
# 394       2                  vw pickup
# 395       1              dodge rampage
# 396       1                ford ranger
# 397       1                 chevy s-10
#
# [392 rows x 9 columns]

# %% [markdown]
# ### 5.3.1 ホールドアウト検証

# %% [markdown]
# #### データの分割
# ```df.sample```だと、抽出されなかった側のデータをどう引っ張ってくるかが分からないので```train_test_split```を使った方が良い

# %%
train_df = df.sample(frac=0.5, random_state=1)

# %%
train_df, test_df = train_test_split(df, train_size=0.5, random_state=1)

# %%
train_df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 32   25.0          4         113.0          95    2228          14.0    71
# 57   26.0          4          91.0          70    1955          20.5    71
# 259  20.6          6         231.0         105    3380          15.8    78
# 34   19.0          6         232.0         100    2634          13.0    71
# 271  21.1          4         134.0          95    2515          14.8    78
# ..    ...        ...           ...         ...     ...           ...   ...
# 206  28.0          4          97.0          75    2155          16.4    76
# 258  19.4          6         232.0          90    3210          17.2    78
# 74   13.0          8         307.0         130    4098          14.0    72
# 238  30.5          4          98.0          63    2051          17.0    77
# 39   14.0          8         350.0         165    4209          12.0    71
#
#      origin                              name
# 32        3                     toyota corona
# 57        1                  plymouth cricket
# 259       1             buick century special
# 34        1                       amc gremlin
# 271       3         toyota celica gt liftback
# ..      ...                               ...
# 206       3                    toyota corolla
# 258       1                       amc concord
# 74        1  chevrolet chevelle concours (sw)
# 238       1                chevrolet chevette
# 39        1                  chevrolet impala
#
# [196 rows x 9 columns]

# %%
lr_model = LinearRegression()
lr_model.fit(np.array(train_df.horsepower).reshape(-1, 1), train_df.mpg)
# Out:
# LinearRegression()

# %%
mpg_pred = lr_model.predict(np.array(test_df.horsepower).reshape(-1, 1))
mpg_pred.shape
# Out:
# (196,)

# %% [markdown]
# #### MSEの算出

# %%
mse(test_df.mpg, mpg_pred)
# Out:
# 24.80212062059356

# %% [markdown]
# #### 多項回帰

# %%
cubic_features = PF(degree=3, include_bias = False)

train_c_horsepower = cubic_features.fit_transform(np.array(train_df.horsepower).reshape(-1, 1))
train_q_horsepower = train_c_horsepower[:, :2]

test_c_horsepower = cubic_features.fit_transform(np.array(test_df.horsepower).reshape(-1, 1))
test_q_horsepower = test_c_horsepower[:, :2]

# %%
lr_q_model = LinearRegression()
lr_q_model.fit(train_q_horsepower, train_df.mpg)

lr_c_model = LinearRegression()
lr_c_model.fit(train_c_horsepower, train_df.mpg)
# Out:
# LinearRegression()

# %%
q_mpg_pred = lr_q_model.predict(test_q_horsepower)
c_mpg_pred = lr_c_model.predict(test_c_horsepower)

# %%
mse(test_df.mpg, q_mpg_pred), mse(test_df.mpg, c_mpg_pred)
# Out:
# (18.848292603275663, 18.805111358604574)

# %% [markdown]
# ### 5.3.2 1つ抜き交差検証
# 2次、3次の結果は確認していない

# %%
loo = LeaveOneOut()
loo_df = loo.split(df)

mses = list()

start = time.time()
for i, j in loo_df:
    train_horsepower =  df.horsepower.to_numpy()[i].reshape(-1, 1)
    test_horsepower = df.horsepower.to_numpy()[j].reshape(-1, 1)
    train_mpg = df.mpg.to_numpy()[i]
    test_mpg = df.mpg.to_numpy()[j]
    
    lr_model.fit(train_horsepower, train_mpg)
    lr_model.predict(test_horsepower)
    mses.append(mse(test_mpg, lr_model.predict(test_horsepower)))
loo_finish = time.time() - start

df_mses = pd.DataFrame(mses)
df_mses.describe()
# Out:
#                 0
# count  392.000000
# mean    24.231514
# std     36.844340
# min      0.003546
# 25%      2.074089
# 50%      9.727509
# 75%     31.683015
# max    289.448955

# %% [markdown]
# ### 5.3.3 k分割交差検証

# %%
kf = KFold(n_splits=10)
kf_df = kf.split(df)

mses = list()

start = time.time()
for i, j in kf_df:
    train_horsepower =  df.horsepower.to_numpy()[i].reshape(-1, 1)
    test_horsepower = df.horsepower.to_numpy()[j].reshape(-1, 1)
    train_mpg = df.mpg.to_numpy()[i]
    test_mpg = df.mpg.to_numpy()[j]
    
    lr_model.fit(train_horsepower, train_mpg)
    lr_model.predict(test_horsepower)
    mses.append(mse(test_mpg, lr_model.predict(test_horsepower)))
kf_finish = time.time() - start

df_mses = pd.DataFrame(mses)
df_mses.describe()
# Out:
#                0
# count  10.000000
# mean   27.439934
# std    15.295147
# min    15.557633
# 25%    17.393265
# 50%    23.098370
# 75%    27.992216
# max    65.934896

# %%
loo_finish / kf_finish
# Out:
# 26.652291105121293

# %% [markdown]
# ### 5.3.4 ブートストラップ

# %%
idx = df.index.to_numpy()

# %%
df.horsepower.to_numpy()[sample_idx].reshape(-1, 1)
# Out:
# array([[110],
#        [120],
#        [ 95],
#        [130],
#        [ 90],
#        [ 95],
#        [225],
#        [ 90],
#        [105],
#        [ 90],
#        [ 97],
#        [ 46],
#        [153],
#        [ 75],
#        [150],
#        [ 63],
#        [215],
#        [158],
#        [ 70],
#        [ 75],
#        [ 69],
#        [140],
#        [145],
#        [ 74],
#        [ 86],
#        [165],
#        [112],
#        [ 62],
#        [ 75],
#        [140],
#        [ 80],
#        [112],
#        [215],
#        [ 76],
#        [ 75],
#        [ 70],
#        [100],
#        [140],
#        [ 65],
#        [ 88],
#        [135],
#        [ 95],
#        [ 88],
#        [ 84],
#        [ 67],
#        [ 75],
#        [ 88],
#        [ 83],
#        [ 90],
#        [180],
#        [175],
#        [ 80],
#        [110],
#        [140],
#        [ 70],
#        [ 65],
#        [ 83],
#        [208],
#        [ 85],
#        [139],
#        [ 69],
#        [198],
#        [225],
#        [ 76],
#        [ 84],
#        [105],
#        [142],
#        [150],
#        [140],
#        [ 97],
#        [105],
#        [100],
#        [140],
#        [115],
#        [ 84],
#        [ 85],
#        [ 88],
#        [ 70],
#        [105],
#        [ 48],
#        [193],
#        [105],
#        [ 90],
#        [ 66],
#        [ 83],
#        [ 92],
#        [145],
#        [ 68],
#        [ 86],
#        [100],
#        [130],
#        [110],
#        [140],
#        [ 95],
#        [ 52],
#        [105],
#        [150],
#        [165],
#        [ 65],
#        [ 95],
#        [ 60],
#        [105],
#        [ 52],
#        [170],
#        [ 95],
#        [ 65],
#        [ 60],
#        [ 60],
#        [ 85],
#        [ 88],
#        [ 60],
#        [ 69],
#        [ 46],
#        [150],
#        [120],
#        [150],
#        [ 92],
#        [ 70],
#        [ 84],
#        [ 66],
#        [132],
#        [ 70],
#        [ 95],
#        [ 75],
#        [ 88],
#        [105],
#        [220],
#        [ 75],
#        [112],
#        [ 97],
#        [175],
#        [175],
#        [ 88],
#        [ 84],
#        [139],
#        [ 95],
#        [ 65],
#        [175],
#        [155],
#        [110],
#        [110],
#        [150],
#        [ 70],
#        [ 90],
#        [ 97],
#        [ 88],
#        [ 96],
#        [150],
#        [ 67],
#        [ 78],
#        [ 88],
#        [110],
#        [ 90],
#        [ 67],
#        [110],
#        [130],
#        [138],
#        [ 85],
#        [ 84],
#        [113],
#        [ 75],
#        [ 70],
#        [ 74],
#        [ 76],
#        [110],
#        [ 78],
#        [ 70],
#        [ 61],
#        [140],
#        [ 80],
#        [ 48],
#        [148],
#        [ 88],
#        [105],
#        [ 95],
#        [125],
#        [ 88],
#        [ 90],
#        [ 94],
#        [ 85],
#        [ 95],
#        [130],
#        [ 88],
#        [ 95],
#        [ 75]])

# %%
idx = [i for i in range(len(df))]
model_result = {'coef': [], 'intercept': []}

for i in range(1000):
    sample_idx = np.random.choice(idx, len(idx))
    train_horsepower =  df.horsepower.to_numpy()[sample_idx].reshape(-1, 1)
    train_mpg = df.mpg.to_numpy()[sample_idx]
    lr_model.fit(train_horsepower, train_mpg)
    model_result['coef'].append(lr_model.coef_[0])
    model_result['intercept'].append(lr_model.intercept_)

model_result_df = pd.DataFrame(model_result)
model_result_df
# Out:
#          coef  intercept
# 0   -0.161855  40.337288
# 1   -0.163838  40.468166
# 2   -0.160446  40.355379
# 3   -0.150274  39.443452
# 4   -0.148791  38.987215
# ..        ...        ...
# 995 -0.156319  40.108818
# 996 -0.158825  39.853875
# 997 -0.155694  39.262025
# 998 -0.157266  39.959454
# 999 -0.153063  39.841498
#
# [1000 rows x 2 columns]

# %%
model_result_df.describe()
# Out:
#               coef    intercept
# count  1000.000000  1000.000000
# mean     -0.158203    39.959186
# std       0.007626     0.880015
# min      -0.185048    37.078968
# 25%      -0.162961    39.361923
# 50%      -0.157952    39.952691
# 75%      -0.153287    40.508845
# max      -0.134052    43.114550
